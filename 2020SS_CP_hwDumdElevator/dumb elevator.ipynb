# %%
    a = 1 
    while True:
        d = input('going to floor 1~7: ')
        if(d is '1'):
            c = 1
            e = a-c
            if(e>0):
                print(a)
                while(e > 1):
                    print ('↓')
                    e-=1
                print(c)
                print('arrived')
                a=c
            elif(e==0):
                print('you are in level 1')
            else:
                print(c)
                while(e<-1):
                    print ('↑')
                    e+=1
                print(a)
                print('arrived')
                a=c
        elif(d is '2'):
            c = 2
            e = a-c
            if(e>0):
                print(a)
                while(e >= 1):
                    print ('↓')
                    e-=1
                print(c)
                print('arrived')
                a=c
            elif(e==0):
                print('you are in level 2')
            else:
                print(c)
                while(e<=-1):
                    print ('↑')
                    e+=1
                print(a)
                print('arrived')
                a=c
        elif(d is '3'):
            c = 3
            e = a-c
            if(e>0):
                print(a)
                while(e >= 1):
                    print ('↓')
                    e-=1
                print(c)
                print('arrived')
                a=c
            elif(e==0):
                print('you are in level 3')
            else:
                print(c)
                while(e<=-1):
                    print ('↑')
                    e+=1
                print(a)
                print('arrived')
                a=c
        elif(d is '4'):
            c = 4
            e = a-c
            if(e>0):
                print(a)
                while(e >= 1):
                    print ('↓')
                    e-=1
                print(c)
                print('arrived')
                a=c
            elif(e==0):
                print('you are in level 4')
            else:
                print(c)
                while(e<=-1):
                    print ('↑')
                    e+=1
                print(a)
                print('arrived')
                a=c
        elif(d is '5'):
            c = 5
            e = a-c
            if(e>0):
                print(a)
                while(e >= 1):
                    print ('↓')
                    e-=1
                print(c)
                print('arrived')
                a=c
            elif(e==0):
                print('you are in level 5')
            else:
                print(c)
                while(e<=-1):
                    print ('↑')
                    e+=1
                print(a)
                print('arrived')
                a=c  
        elif(d is '6'):
            c = 6
            e = a-c
            if(e>0):
                print(a)
                while(e >= 1):
                    print ('↓')
                    e-=1
                print(c)
                print('arrived')
                a=c
            elif(e==0):
                print('you are in level 6')
            else:
                print(c)
                while(e<=-1):
                    print ('↑')
                    e+=1
                print(a)
                print('arrived')
                a=c  
        elif(d is '7'):
            c = 7
            e = a-c
            if(e>0):
                print(a)
                while(e >= 1):
                    print ('↓')
                    e-=1
                print(c)
                print('arrived')
                a=c
            elif(e==0):
                print('you are in level 7')
            else:
                print(c)
                while(e<=-1):
                    print ('↑')
                    e+=1
                print(a)
                print('arrived')
                a=c        
        else:
            print('out of bound')
# Out:
# going to floor 1~7: 1
# you are in level 1
# going to floor 1~7: 4
# 4
# ↑
# ↑
# ↑
# 1
# arrived
# going to floor 1~7: 7
# 7
# ↑
# ↑
# ↑
# 4
# arrived
# going to floor 1~7: 2
# 7
# ↓
# ↓
# ↓
# ↓
# ↓
# 2
# arrived
# going to floor 1~7: 8
# out of bound
# going to floor 1~7: a
# out of bound
